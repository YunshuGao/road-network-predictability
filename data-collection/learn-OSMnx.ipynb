# %%
import osmnx as ox
ox.plot_graph(ox.graph_from_place('Modena,Italy'))
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
data=ox.plot_graph(ox.graph_from_place('Modena,Italy'))

# %%
print(f'Number of edges: {data.num_edges}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\GAOYUN~1\AppData\Local\Temp/ipykernel_14232/893802654.py in <module>
# ----> 1 print(f'Number of edges: {data.num_edges}')
#
# AttributeError: 'tuple' object has no attribute 'num_edges'
